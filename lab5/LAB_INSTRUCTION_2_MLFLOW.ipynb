# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
#
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
#
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5000
# ```
#
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5000

# %% [markdown]
# To verify if the server runs properly, let's connect to git:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5001")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5001

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2025/11/05 12:09:50 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/nicolas/studia/2_sem/MLOps/lab5/mlflow-artifacts/1', creation_time=1762340990365, experiment_id='1', last_update_time=1762340990365, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()
            
            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:5001/#/experiments/1/runs/491f1c847dfb4485a43877d456ce01b4
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
#
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 🏃 View run Decision Tree at: http://localhost:5001/#/experiments/1/runs/3b61318f387046afa8e517b39870610e
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:5001/#/experiments/1/runs/8729a70238f34b10995828622957c208
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/11/05 12:11:37 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:38 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:39 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:40 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:41 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:41 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:5001/#/experiments/1/runs/02068c2fb56f47a998d74938bc9b5b5c
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/11/05 12:11:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:42 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:43 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:11:43 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5001/#/experiments/1/runs/3e1d50aaab1a444aa1c9a3d476ddc3ca
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.linear_model import ElasticNet, SGDRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.kernel_ridge import KernelRidge

model_list_2 = [
    ("Elastic Net", ElasticNet(alpha=0.5, random_state=42)),
    ("SGD Regressor", SGDRegressor(penalty="elasticnet", random_state=42)),
    ("Support Vecor Regressor", SVR()),
    ("AdaBoost Regressor", AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=4), n_estimators=300, random_state=42)),
    ("Kernel Ridge", KernelRidge()),
]

# %%
fit_sklearn_models_with_cv(model_list_2, X_train, X_test, y_train, y_test)
# Out:
# 2025/11/05 12:49:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:04 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Elastic Net:
#   RMSE: 36769.77
#   MAE: 24743.69
#   R^2: 0.763
#   CV R^2 (mean ± std): 0.717 ± 0.017
# 🏃 View run Elastic Net at: http://localhost:5001/#/experiments/1/runs/05fe2b43bb4e422fa9ed0f843e57ce17
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# SGD Regressor:
#   RMSE: 24243.57
#   MAE: 17359.70
#   R^2: 0.897
#   CV R^2 (mean ± std): 0.890 ± 0.031
# 🏃 View run SGD Regressor at: http://localhost:5001/#/experiments/1/runs/add6950690c04b6897e67dd4d9b887f6
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Support Vecor Regressor:
#   RMSE: 77482.01
#   MAE: 54914.40
#   R^2: -0.051
#   CV R^2 (mean ± std): -0.103 ± 0.070
# 🏃 View run Support Vecor Regressor at: http://localhost:5001/#/experiments/1/runs/9634ec8e18ff4321b8f6b84ae52f433d
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
# 2025/11/05 12:49:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:08 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:09 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:10 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:11 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2025/11/05 12:49:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# AdaBoost Regressor:
#   RMSE: 28491.52
#   MAE: 19587.57
#   R^2: 0.858
#   CV R^2 (mean ± std): 0.859 ± 0.048
# 🏃 View run AdaBoost Regressor at: http://localhost:5001/#/experiments/1/runs/f4a9d9bc0d4d4696a4904841670b9464
# 🧪 View experiment at: http://localhost:5001/#/experiments/1
#
# Kernel Ridge:
#   RMSE: 23850.13
#   MAE: 16905.30
#   R^2: 0.900
#   CV R^2 (mean ± std): 0.892 ± 0.036
# 🏃 View run Kernel Ridge at: http://localhost:5001/#/experiments/1/runs/635ec55791594e959340d886802155cb
# 🧪 View experiment at: http://localhost:5001/#/experiments/1

# %% [markdown]
# Didn't manage to beat the Gradient Boosting from previous run

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2025/11/05 12:58:52 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/nicolas/studia/2_sem/MLOps/lab5/mlflow-artifacts/2', creation_time=1762343932301, experiment_id='2', last_update_time=1762343932301, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 59966.88, MAE: 49832.11 R^2: 0.502
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 38704.24, MAE: 25679.63 R^2: 0.754
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 30132.90, MAE: 21886.36 R^2: 0.865
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 52071.96, MAE: 37917.94 R^2: 0.525
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 42702.74, MAE: 30513.11 R^2: 0.686
#
# Cross-validation complete. Mean R^2: 0.666 (+/- 0.137)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.666 (+/- 0.137)
#
# Cross-Validation Performance:
#   R^2: 0.891
#   RMSE: 24948.21
#   MAE: 17550.87
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5001/#/experiments/2/runs/4131101507aa46008d01292a099c2e0d
# 🧪 View experiment at: http://localhost:5001/#/experiments/2

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 2. **Model size** - number of hidden units here:
#
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 3. **Dropout rate:**
#
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 4. **Batch size:**
#
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 5. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
#
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
# Strategy 1: Strong regularization with smaller network
config_1 = {
    "name": "strong_regularization",
    "hidden_units": 64,
    "dropout": 0.5,
    "learning_rate": 0.001,
    "epochs": 200,
    "batch_size": 64,
}

# Strategy 2: Very small network, minimal dropout
config_2 = {
    "name": "tiny_network",
    "hidden_units": 32,
    "dropout": 0.2,
    "learning_rate": 0.01,
    "epochs": 100,
    "batch_size": 128,
}

# Strategy 3: Moderate size, aggressive dropout
config_3 = {
    "name": "aggressive_dropout",
    "hidden_units": 96,
    "dropout": 0.6,
    "learning_rate": 0.005,
    "epochs": 180,
    "batch_size": 48,
}

# Strategy 4: Large batches, early stopping friendly
config_4 = {
    "name": "large_batch",
    "hidden_units": 80,
    "dropout": 0.3,
    "learning_rate": 0.002,
    "epochs": 120,
    "batch_size": 256,
}

# Strategy 5: Very low learning rate, patient training
config_5 = {
    "name": "patient_training",
    "hidden_units": 100,
    "dropout": 0.4,
    "learning_rate": 0.0005,
    "epochs": 250,
    "batch_size": 32,
}

# Strategy 6: Minimal capacity
config_6 = {
    "name": "minimal_capacity",
    "hidden_units": 48,
    "dropout": 0.35,
    "learning_rate": 0.008,
    "epochs": 80,
    "batch_size": 96,
}

# Strategy 7: Medium network, balanced approach
config_7 = {
    "name": "balanced_medium",
    "hidden_units": 72,
    "dropout": 0.45,
    "learning_rate": 0.003,
    "epochs": 150,
    "batch_size": 80,
}

# Strategy 8: High dropout, moderate everything else
config_8 = {
    "name": "dropout_heavy",
    "hidden_units": 88,
    "dropout": 0.7,
    "learning_rate": 0.004,
    "epochs": 160,
    "batch_size": 56,
}

# Strategy 9: Micro network with minimal dropout (simplicity approach)
config_9 = {
    "name": "micro_simplicity",
    "hidden_units": 24,
    "dropout": 0.15,
    "learning_rate": 0.015,
    "epochs": 60,
    "batch_size": 160,
}

# Strategy 10: Wide and shallow with heavy regularization
config_10 = {
    "name": "wide_shallow_regularized",
    "hidden_units": 144,
    "dropout": 0.55,
    "learning_rate": 0.0008,
    "epochs": 220,
    "batch_size": 40,
}

# %%
configs = [config_1, config_2, config_3, config_4, config_5, config_6, config_7, config_8, config_9, config_10]

# %%
for config in configs:
    training_config = base_config | config

    trainer = PyTorchTrainer(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for strong_regularization...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 66909.81, MAE: 57403.46 R^2: 0.380
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 61383.75, MAE: 50347.99 R^2: 0.382
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 56265.16, MAE: 43138.38 R^2: 0.528
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 73131.62, MAE: 58568.82 R^2: 0.064
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 48299.25, MAE: 36863.60 R^2: 0.598
#
# Cross-validation complete. Mean R^2: 0.391 (+/- 0.184)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.391 (+/- 0.184)
#
# Cross-Validation Performance:
#   R^2: 0.443
#   RMSE: 56432.69
#   MAE: 44835.30
# Test Set Performance:
# ==================================================
# FINAL RESULTS for strong_regularization:
#
# ==================================================
# 🏃 View run strong_regularization at: http://localhost:5001/#/experiments/2/runs/76e8643287f544188ab48863741ab71e
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for tiny_network...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 78311.62, MAE: 65455.73 R^2: 0.150
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 61283.95, MAE: 50994.94 R^2: 0.384
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 66846.88, MAE: 54370.91 R^2: 0.334
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 75801.34, MAE: 49511.12 R^2: -0.006
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 76640.55, MAE: 49058.45 R^2: -0.011
#
# Cross-validation complete. Mean R^2: 0.170 (+/- 0.166)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.170 (+/- 0.166)
#
# Cross-Validation Performance:
#   R^2: -0.250
#   RMSE: 84516.07
#   MAE: 73548.24
# Test Set Performance:
# ==================================================
# FINAL RESULTS for tiny_network:
#
# ==================================================
# 🏃 View run tiny_network at: http://localhost:5001/#/experiments/2/runs/f9c4ae752aae46e5963f99fd38ce7ea6
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for aggressive_dropout...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 34248.30, MAE: 26139.95 R^2: 0.837
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 72258.00, MAE: 62213.89 R^2: 0.144
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 56349.17, MAE: 43697.96 R^2: 0.527
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 26678.98, MAE: 20129.35 R^2: 0.875
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 35341.34, MAE: 26834.49 R^2: 0.785
#
# Cross-validation complete. Mean R^2: 0.634 (+/- 0.273)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.634 (+/- 0.273)
#
# Cross-Validation Performance:
#   R^2: 0.895
#   RMSE: 24474.30
#   MAE: 16818.81
# Test Set Performance:
# ==================================================
# FINAL RESULTS for aggressive_dropout:
#
# ==================================================
# 🏃 View run aggressive_dropout at: http://localhost:5001/#/experiments/2/runs/c79d7ebba46143b3998d1ad35f5323ef
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for large_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 62427.32, MAE: 46226.16 R^2: 0.460
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 69848.45, MAE: 50405.36 R^2: 0.200
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 68000.22, MAE: 55882.69 R^2: 0.311
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 64775.48, MAE: 46742.86 R^2: 0.266
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 54262.84, MAE: 40653.13 R^2: 0.493
#
# Cross-validation complete. Mean R^2: 0.346 (+/- 0.113)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.346 (+/- 0.113)
#
# Cross-Validation Performance:
#   R^2: 0.301
#   RMSE: 63175.83
#   MAE: 47426.93
# Test Set Performance:
# ==================================================
# FINAL RESULTS for large_batch:
#
# ==================================================
# 🏃 View run large_batch at: http://localhost:5001/#/experiments/2/runs/c24cb181f9cb41f5a4704ef12195462a
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for patient_training...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 46427.38, MAE: 35546.48 R^2: 0.701
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 44752.43, MAE: 33643.37 R^2: 0.672
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 51359.86, MAE: 40170.62 R^2: 0.607
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 55166.34, MAE: 34013.07 R^2: 0.467
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 53727.00, MAE: 35832.28 R^2: 0.503
#
# Cross-validation complete. Mean R^2: 0.590 (+/- 0.092)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.590 (+/- 0.092)
#
# Cross-Validation Performance:
#   R^2: 0.676
#   RMSE: 43016.68
#   MAE: 30557.74
# Test Set Performance:
# ==================================================
# FINAL RESULTS for patient_training:
#
# ==================================================
# 🏃 View run patient_training at: http://localhost:5001/#/experiments/2/runs/b7faa218c0484c89811b19e3d6999d91
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for minimal_capacity...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 47716.74, MAE: 36263.56 R^2: 0.684
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 97048.26, MAE: 62798.79 R^2: -0.544
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 80675.82, MAE: 65142.32 R^2: 0.030
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 85750.25, MAE: 61942.50 R^2: -0.287
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 59791.14, MAE: 46614.85 R^2: 0.385
#
# Cross-validation complete. Mean R^2: 0.054 (+/- 0.443)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.054 (+/- 0.443)
#
# Cross-Validation Performance:
#   R^2: 0.183
#   RMSE: 68304.49
#   MAE: 43582.98
# Test Set Performance:
# ==================================================
# FINAL RESULTS for minimal_capacity:
#
# ==================================================
# 🏃 View run minimal_capacity at: http://localhost:5001/#/experiments/2/runs/b4f090453e6d4163a7439bdd30d2f9da
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for balanced_medium...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 51832.00, MAE: 40562.11 R^2: 0.628
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 64298.16, MAE: 52734.95 R^2: 0.322
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 70125.33, MAE: 49211.68 R^2: 0.267
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 62760.98, MAE: 39025.50 R^2: 0.311
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 61806.33, MAE: 48289.89 R^2: 0.342
#
# Cross-validation complete. Mean R^2: 0.374 (+/- 0.129)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.374 (+/- 0.129)
#
# Cross-Validation Performance:
#   R^2: -0.143
#   RMSE: 80828.44
#   MAE: 69848.45
# Test Set Performance:
# ==================================================
# FINAL RESULTS for balanced_medium:
#
# ==================================================
# 🏃 View run balanced_medium at: http://localhost:5001/#/experiments/2/runs/5c491b7d05544c6787cc4a3cd95dae75
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for dropout_heavy...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 78727.95, MAE: 67171.33 R^2: 0.141
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 35214.40, MAE: 26542.62 R^2: 0.797
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 76540.12, MAE: 64271.55 R^2: 0.127
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 65612.48, MAE: 54207.44 R^2: 0.247
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 62934.64, MAE: 52440.80 R^2: 0.318
#
# Cross-validation complete. Mean R^2: 0.326 (+/- 0.246)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.326 (+/- 0.246)
#
# Cross-Validation Performance:
#   R^2: 0.091
#   RMSE: 72048.55
#   MAE: 61502.34
# Test Set Performance:
# ==================================================
# FINAL RESULTS for dropout_heavy:
#
# ==================================================
# 🏃 View run dropout_heavy at: http://localhost:5001/#/experiments/2/runs/6fc485e80e1b4b719f8dea38e239bd71
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for micro_simplicity...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 51143.75, MAE: 40391.91 R^2: 0.638
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 75286.03, MAE: 58069.92 R^2: 0.071
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 64338.36, MAE: 46912.85 R^2: 0.383
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 75471.41, MAE: 51537.87 R^2: 0.003
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 55330.12, MAE: 43260.15 R^2: 0.473
#
# Cross-validation complete. Mean R^2: 0.314 (+/- 0.241)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.314 (+/- 0.241)
#
# Cross-Validation Performance:
#   R^2: -0.175
#   RMSE: 81920.48
#   MAE: 71393.16
# Test Set Performance:
# ==================================================
# FINAL RESULTS for micro_simplicity:
#
# ==================================================
# 🏃 View run micro_simplicity at: http://localhost:5001/#/experiments/2/runs/9252a4c496ef45d1a4167db813f3be8d
# 🧪 View experiment at: http://localhost:5001/#/experiments/2
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for wide_shallow_regularized...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 43642.61, MAE: 33821.30 R^2: 0.736
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 49994.08, MAE: 37132.16 R^2: 0.590
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 49330.38, MAE: 37851.27 R^2: 0.637
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 53099.53, MAE: 34340.56 R^2: 0.507
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 43923.98, MAE: 30779.40 R^2: 0.668
#
# Cross-validation complete. Mean R^2: 0.628 (+/- 0.077)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.628 (+/- 0.077)
#
# Cross-Validation Performance:
#   R^2: 0.394
#   RMSE: 58860.55
#   MAE: 47693.52
# Test Set Performance:
# ==================================================
# FINAL RESULTS for wide_shallow_regularized:
#
# ==================================================
# 🏃 View run wide_shallow_regularized at: http://localhost:5001/#/experiments/2/runs/6caef9ad704b4baa80c178d1e33c5330
# 🧪 View experiment at: http://localhost:5001/#/experiments/2

# %% [markdown]
# ### 2. Analyze results in MLflow UI.

# %% [markdown]
# ![image](test_rmse-test_mae.png)

# %% [markdown]
# I was not able to actually improve the model performance compared to the initial PyTorch experiment. All models proposed by me performed significantly worse than the base one.

# %% [markdown]
# ### 3. What changes impacted the model performance the most.
#
# From what I observed, all the parameters are significat for the model performance. However, the most impactful that I suspect are:
# - learning rate
# - number of hidden units
#
# With lower number of hidden units, the model was not able to capture the complexity of the data, leading to underfitting. Additionally, decreasing the learning rate too much resulted in slow convergence, preventing the model from reaching an optimal solution within the given number of epochs.
#
# Low number of hidden units also seem to leed to overfitting, because the small models had the highest tests errors while having one of the lowest training errors.
#
# I would say that this case study showed that choosing right hyperparameters for a model is a complex task, as they interact with each other in non-trivial ways and there is an uphill battle between balancing parameters that influece each other e.g.:
#
# - number of hidden units vs dropout rate
# - learning rate vs batch size

# %% [markdown]
# ![Image](final_model_train_mse.png)

# %% [markdown]
# ### 4. Comparison of Scikit-learn and PyTorch results

# %% [markdown]
# To be honest, I see quite inverse situation here. The first PyTorch experiment shows quite good test performance (MAE around 17500 and RMSE around 25000) with not so good CV results (MAE between 22000-50000 and RMSE between 30000-60000). This indicates some underfitting on the cross-validation folds, the model generalizes well on the test set. Also, the R2 on the test set is around 0.89, whereas the mean R2 on the CV folds equals 0.66.
#
# On the other hand, the first Scikit-learn experiment with Gradient Boosting shows very good training performance (MAE around 9000, RMSE around 14000 and R2 around 0.98), but the test performance is significantly worse (MAE around 14000, RMSE around 21500 and R2 around 0.90), indicating some overfitting on the training data.
